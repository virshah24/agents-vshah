# %% [markdown]
# ## Content Creation with a multi-agent approach.

# %%
import logging
import json
import textwrap
import re

from dotenv import load_dotenv
from semantic_kernel import Kernel
from semantic_kernel.agents import ChatCompletionAgent, ChatHistoryAgentThread, AgentGroupChat
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion, AzureChatPromptExecutionSettings
from semantic_kernel.filters import FunctionInvocationContext
from semantic_kernel.functions import KernelFunctionFromPrompt, KernelArguments
from semantic_kernel.contents import FunctionCallContent, FunctionResultContent
from semantic_kernel.contents.chat_message_content import ChatMessageContent
from semantic_kernel.agents.strategies import KernelFunctionTerminationStrategy, KernelFunctionSelectionStrategy
from pydantic import BaseModel, Field
from typing import List
from IPython.display import display, Markdown

#ai_agent_sdk
import asyncio
from typing import Annotated

from azure.identity.aio import DefaultAzureCredential

from semantic_kernel.agents import AzureAIAgent, AzureAIAgentSettings
from semantic_kernel.functions import kernel_function

# Load environment variables from .env file
load_dotenv()

# NOTE: This is all that is required to enable logging.
# Set the desired level to INFO, DEBUG, etc.
logging.basicConfig(level=logging.WARNING)

# %%
# This just helps to make the output more readable.
# Just click play on the cell to run it, and move on. :)

class SocialMediaPost(BaseModel):
    platform: str = Field(..., description="The social media platform where the post will be published (e.g., Twitter, LinkedIn).")
    content: str = Field(..., description="The content of the social media post, including any hashtags or mentions.")

class Article(BaseModel):
    title: str
    content: str
    call_to_action: str

class ContentOutput(BaseModel):
    article: Article
    social_media_posts: List[SocialMediaPost]

# %%
# Some casual things for formatting.

intermediate_steps: list[ChatMessageContent] = []

async def handle_intermediate_steps(message: ChatMessageContent) -> None:
    intermediate_steps.append(message)

output_settings = AzureChatPromptExecutionSettings(response_format=ContentOutput)

# %%
from semantic_kernel.agents.strategies import TerminationStrategy

class ApprovalTerminationStrategy(TerminationStrategy):
    """A strategy for determining when an agent should terminate."""

    async def should_agent_terminate(self, agent, history):
        """Check if the agent should terminate."""
        return "yes" in history[-1].content.lower()

# %%
# The selection function is used to determine which agent should take the next turn in the conversation,
# based on the conversation history and the rules defined in the prompt.

selection_function = KernelFunctionFromPrompt(
    function_name="selection",
    prompt="""
    Based on the conversation history, determine the next agent to take a turn. 
    Only return the name of the agent from the following list:
    - LeadResearchAgent
    - DataAnalystAgent
    - ContentCreatorAgent
    - QualityAssuranceAgent

    Rules:
    - LeadResearchAgent starts first.
    - After LeadResearchAgent, DataAnalystAgent speaks.
    - After DataAnalystAgent, ContentCreatorAgent speaks.
    - After ContentCreatorAgent speaks, the QualityAssuranceAgent speaks.
    - If the QualityAssuranceAgent requests changes, restart the cycle with the LeadResearchAgent.
    - If the QualityAssuranceAgent approves the content, the cycle ends.
   
    History:
    {{$history}}
    """,
)

# %%
# The Search plugin is used to search for information on the web. This allows us to get more up-to-date information.
from search import SearchPlugin

ai_agent_settings = AzureAIAgentSettings(model_deployment_name="gpt-4o-mini")

async with (
    DefaultAzureCredential() as creds,
    AzureAIAgent.create_client(
        credential=creds,
    ) as client,
):
    
    # 1. Create an agent on the Azure AI agent service
    agent_definition_lr = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name="LeadResearchAgent",
         instructions=(
        """
        As the Lead Research Analyst at a premier content platform, you specialize in finding information that best fits the needs of your
        audience. Your primary responsibility is to ensure that the content produced by your team is not only accurate but also timely and
        relevant. You will do this by conducting in-depth research. You will need to search the web to get this content.
        """)
    )

    # 1. Create an agent on the Azure AI agent service
    agent_definition_da = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name="DataAnalystAgent",
        instructions=(
        """
        You are a Chief Data Strategist, responsible for synthesizing complex data into actionable insights that can be transformed into useful content.
        As the Chief Data Strategist at an advisory firm, your role involves analyzing extensive datasets to identify trends and opportunities that inform investment strategies. Your expertise is essential for conducting thorough research.

        Your tasks are:
        • Analyze data with a focus on uncovering patterns, opportunities, and risks that could be leveraged in content creation. 
        • Provide actionable insights that can be transformed into content, such as articles, reports, or social media posts.
        • Collaborate with the Lead Research Analyst to ensure that the content produced is not only accurate but also timely and relevant.

        Your expected output is a comprehensive analysis report that highlights key market trends and actionable insights. The report should include links to the data visualizations, charts, or other related images and clear recommendations for content creation.
        Do not ask for feedback or approval, just create the content.
        """),
    )

    # 1. Create an agent on the Azure AI agent service
    agent_definition_cc = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name="ContentCreatorAgent",
        instructions=(
        """
        As the Creative Content Director, your objective is to create and supervise the production of high-quality content that educates and engages the audience.
        In your role at a leading publishing firm, you specialize in developing narratives that connect with readers. You successfully blend thorough analysis with compelling storytelling to produce content that fosters engagement and trust.
        You will be working with the Lead Research Analyst and Chief Data Strategist to create content that is not only accurate but also timely and relevant.
        Your will be responsible for creating a blog post and social media posts that promote the blog post. Any twitter posts, Instagram posts, facebook posts, X posts, and other posts should be very short and easy to understand, and should sound like clickbait.

        Your tasks are:
            Based on the insights provided by the LeadResearchAgent and DataAnalystAgent agents, create high-quality, engaging content that educates and informs the target audience.
            Produce a blog post that clearly conveys the key findings and recommendations.
            Create social media posts that promote the blog post and engage the audience.
            Incorporate the links to data visualizations, infographics, or other multimedia elements to enhance the content where applicable. The blog post has to have at least a paragraph for each section.

        Your expected output is a high-quality blog post, and a collection of social media posts, including tweets, LinkedIn updates, and other platform-specific content. The blog post should include a title, a call to action, and links to data visualizations, infographics, or other multimedia elements. 
        Do not ask for feedback or approval, just create the content.
        """),
        )  

    # 1. Create an agent on the Azure AI agent service
    agent_definition_qa = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name="QualityAssuranceAgent",
        instructions=(
        """
        As a Chief Content Officer, your goal is to oversee and refine the content creation process, ensuring that all outputs are accurate, aligned with brand voice, and optimized for engagement. In this role at a leading media company, you are responsible for ensuring that every piece of content meets high editorial standards and provides clear, actionable insights to help the audience make informed decisions.

        Your tasks are:    
        Review and refine the content created to ensure it meets the highest standards of accuracy and clarity. 
        Thoroughly proofread and edit the content, checking for errors and inconsistencies.
        Ensure that the content accurately reflects the key insights and recommendations provided by the DataAnalyst agent and BlogCreatorAgent agents. 
        Ensure that the final content is well-formatted in markdown, using appropriate headers, bullet points, links, links to visualizations and images provided by the other agents and other markdown features to enhance readability and engagement. The blog post has to have at least a paragraph for each section.

        A finalized blog post from the BlogCreatorAgent along with social media posts from SocialCreatorAgent that have all been thoroughly reviewed, and formatted in markdown. The content should be well-structured, with appropriate use of headers, bullet points, links, links to the data visualizations, images, charts and other markdown features to ensure it is both visually appealing and easy to read. The content should be ready for publication and distribution across various channels.
        """),
    )

    agent_definition_lr = await client.agents.get_agent(
            agent_id="asst_h7RYxlc2DZoyQZNb5TXXfcH1",
        )    
    agent_definition_da = await client.agents.get_agent(
            agent_id="asst_vdM0JJ1VQejtc744ccHRsp1V",
        )
    agent_definition_cc = await client.agents.get_agent(
            agent_id="asst_VXihGqZSL5lVHsUjmLh5zw3V",
        )
    agent_definition_qa = await client.agents.get_agent(
            agent_id="asst_vRJ8QNiWl2ky2eip5geUrKOt",
        )
    # 2. Create a Semantic Kernel agent for the Azure AI agent
    # Create the Lead Market Analyst agent. NOTE: The name of the agent must not contain spaces.
    lead_research_agent = AzureAIAgent(
        client=client,
        definition=agent_definition_lr,
        plugins=[SearchPlugin()],  # Add the plugin to the agent
        )

    data_analyst_agent = AzureAIAgent(
        client=client,
        definition=agent_definition_da
        )

    content_creator_agent = AzureAIAgent(
        client=client,
        definition=agent_definition_cc
        )

    quality_assurance_agent = AzureAIAgent(
        client=client,
        definition=agent_definition_qa
        )

    agent_group = AgentGroupChat(
            agents=[lead_research_agent, data_analyst_agent, content_creator_agent, quality_assurance_agent],
            termination_strategy=ApprovalTerminationStrategy(agents=[quality_assurance_agent], maximum_iterations=3),
        )

    # This is the question that will be asked to the agents. It should be a clear and concise question that the agents can work on together.
    #topic = "Inflation in the US and the impact on the stock market in 2025"
    topic = "Vegeterian and Vegan lunch options provided in US school system and weather it needs change"

    initial_message = f"Subject: {topic}\n\nCollaborate to produce structured content output matching the provided schema."
    await agent_group.add_chat_message(message=initial_message)

    final_response = ""
    async for response in agent_group.invoke():
        print(f"# {response.name}:\n{response.content}\n")
        final_response = response.content
# Out:
# Performing search...
# Query: Vegetarian and Vegan lunch options in US schools 2023
# # LeadResearchAgent:
# ### Title: Vegetarian and Vegan Lunch Options in the US School System: Current Status and Recommendations for Change
#
# #### Introduction
# As dietary preferences shift towards vegetarianism and veganism, the need for more inclusive and diverse lunch options in the US school system has grown. This document outlines the current state of vegetarian and vegan options available in schools, factors influencing the need for changes, and recommends potential actions for improvement.
#
# #### Current Options
# 1. **USDA Rules and Regulations**
#    - Recent updates to USDA's school meal standards have expanded access to vegetarian and vegan options, allowing schools to meet the nutritional needs of students with dietary restrictions. Schools must offer sufficient vegetables when including alternatives such as beans, peas, and lentils along with other meals.
#      - [Source: Vegconomist](https://vegconomist.com/health/new-usda-rules-expand-vegan-options-school-meals/)
#
# 2. **Local Initiatives**
#    - Portland Public Schools, Maine, have revamped their vegetarian offerings from a single cold meal to four hot vegan options available across different education levels.
#      - [Source: vkind.com](https://www.vkind.com/problems-with-the-lunch-program-and-how-plant-based-lunches-can-help/)
#
# 3. **Student Demand**
#    - Surveys indicate that over 37% of students are interested in consuming school lunches more frequently if vegetarian and vegan options were readily available. Schools are responding to this demand, expanding their plant-based offerings.
#      - [Source: FoodService Director](https://www.foodservicedirector.com/k-12-schools/k-12-students-want-more-plant-based-options-on-the-menu)
#
# 4. **New Initiatives**
#    - Organizations such as Veganuary are promoting vegan options through campaigns like the Vegan School Lunch Challenge to encourage families to consider more plant-based meals in their lunchboxes.
#      - [Source: VegNews](https://vegnews.com/new-initiatives-vegan-school-lunches)
#
# #### Need for Change
# Despite the positive developments, challenges remain:
# - **Limited Variety**: Many schools continue to offer a very limited range of plant-based options, which can lead to boredom or dissatisfaction among students.
# - **Awareness and Accessibility**: Various stakeholders, including parents and school administration, need more resources about plant-based nutrition to encourage daily plant-based eating among students.
#
# #### Recommendations
# 1. **Broaden Menu Options**
#    - Schools should introduce a wider variety of flavorful and nutritious vegetarian and vegan meals beyond the standard offerings. Engaging local chefs or nutritionists may help create appealing meal options.
#
# 2. **Education and Resources**
#    - Providing educational materials for students and parents advocating for plant-based dieting and innovatively converting some traditional meals to vegan-friendly versions could increase interest and acceptance.
#
# 3. **Data-Driven Decisions**
#    - Conduct comprehensive surveys within schools to assess student preference regularly, allowing for menus to be adapted based on direct feedback from the student body.
#
# 4. **Partnership with Organizations**
#    - Collaboration with plant-based food organizations can expand programs and initiatives aimed at increasing the availability and attractiveness of vegetarian and vegan meals in schools.
#
# #### Conclusion
# As the demand for vegetarian and vegan options grows among students in US schools, it is essential to adapt school meal programs to meet these needs through improved variety and inclusivity. By embracing the dietary changes and preferences of young individuals, schools can promote healthier eating habits and environmental awareness.
#
# # DataAnalystAgent:
# ### Title: Vegetarian and Vegan Lunch Options in the US School System: Current Status and Recommendations for Change
#
# #### Introduction
# As dietary preferences shift towards vegetarianism and veganism, the need for more inclusive and diverse lunch options in the US school system has grown. This document outlines the current state of vegetarian and vegan options available in schools, factors influencing the need for changes, and recommends potential actions for improvement.
#
# #### Current Options
# 1. **USDA Rules and Regulations**
#    - Recent updates to USDA's school meal standards have expanded access to vegetarian and vegan options. Schools must offer sufficient vegetables when including alternatives such as beans, peas, and lentils along with other meals.
#      - [Source: Vegconomist](https://vegconomist.com/health/new-usda-rules-expand-vegan-options-school-meals/)
#
# 2. **Local Initiatives**
#    - Portland Public Schools in Maine have revamped their vegetarian offerings, expanding from a single cold meal to four hot vegan options available across different education levels.
#      - [Source: vkind.com](https://www.vkind.com/problems-with-the-lunch-program-and-how-plant-based-lunches-can-help/)
#
# 3. **Student Demand**
#    - Surveys indicate that over 37% of students are interested in consuming school lunches more frequently if vegetarian and vegan options were readily available. Schools are responding to this demand by expanding their plant-based offerings.
#      - [Source: FoodService Director](https://www.foodservicedirector.com/k-12-schools/k-12-students-want-more-plant-based-options-on-the-menu)
#
# 4. **New Initiatives**
#    - Organizations such as Veganuary are promoting vegan options through campaigns like the Vegan School Lunch Challenge to encourage families to consider more plant-based meals in their lunchboxes.
#      - [Source: VegNews](https://vegnews.com/new-initiatives-vegan-school-lunches)
#
# #### Need for Change
# Despite the positive developments, challenges remain:
# - **Limited Variety**: Many schools continue to offer a very limited range of plant-based options, which can lead to boredom or dissatisfaction among students.
# - **Awareness and Accessibility**: Various stakeholders, including parents and school administration, need more resources about plant-based nutrition to encourage daily plant-based eating among students.
#
# #### Recommendations
# 1. **Broaden Menu Options**
#    - Schools should introduce a wider variety of flavorful and nutritious vegetarian and vegan meals beyond the standard offerings. Engaging local chefs or nutritionists may help create appealing meal options.
#
# 2. **Education and Resources**
#    - Providing educational materials for students and parents advocating for plant-based dieting and innovatively converting some traditional meals to vegan-friendly versions could increase interest and acceptance.
#
# 3. **Data-Driven Decisions**
#    - Conduct comprehensive surveys within schools to assess student preferences regularly, allowing for menus to be adapted based on direct feedback from the student body.
#
# 4. **Partnership with Organizations**
#    - Collaborating with plant-based food organizations can expand programs and initiatives aimed at increasing the availability and attractiveness of vegetarian and vegan meals in schools.
#
# #### Conclusion
# As the demand for vegetarian and vegan options grows among students in US schools, it is essential to adapt school meal programs to meet these needs through improved variety and inclusivity. By embracing the dietary changes and preferences of young individuals, schools can promote healthier eating habits and environmental awareness.
#
# # ContentCreatorAgent:
# ### Social Media Promotions
#
# #### Twitter Posts
# 1. 🌱🍏 "Does your school serve enough plant-based meals? Discover the current state of vegetarian and vegan lunch options in US schools! 👉 [link] #PlantBased #SchoolLunch"
#
# 2. 🚸📚 "37% of students want more veggie options! Are schools listening? Learn about the need for change in our latest blog! 🌿✨ [link] #VeganLunch #HealthySchools"
#
# 3. 🍽️ "Mixed reviews on your school's lunch menu? Explore how we can spice up vegetarian and vegan options! 🌈📊 [link] #SchoolLunchRevolution #EatYourVeggies"
#
# 4. 🌼 Join the #VeganSchoolLunchChallenge! Discover how schools can improve plant-based offerings for healthier choices! 🌿💚 [link] #ChangeIsNow"
#
# #### LinkedIn Post
# "Are we doing enough to provide our students with nutritious vegetarian and vegan lunch options in US schools? Our latest blog delves into the current offerings, the growing student demand, and key recommendations for improvement. Let’s work together to ensure our school meal programs can adapt to the changing dietary preferences of the next generation. Read more: [link] #SchoolNutrition #PlantBasedEating"
#
# #### Instagram Posts
# 1. 📸 [Image of a colorful school meal with veggies] "Are school lunch menus meeting nutritional needs? 🌱 Dive into the world of vegetarian and vegan options in schools! Link in bio! #HealthyEating #SchoolMeals"
#
# 2. 📸 [Image of students enjoying a meal] "Did you know over 37% of students want more plant-based options? 🥗 Check out our blog to learn how schools can meet this demand! #VeganInSchools #LunchGoals"
#
# 3. 📸 [Infographic of vegetarian options in schools] "Explore the current state of veggie and vegan lunches in US schools and learn how we can make a change! 📊 Link in bio! #EatPlants #SchoolLunch"
#
# #### Facebook Posts
# 1. "🌱 Are US schools offering enough vegetarian and vegan lunch options? Our latest blog explores the current landscape and provides recommendations for change! Check it out: [link] #SchoolNutrition #PlantBased"
#
# 2. "🚸 There’s a growing demand for plant-based meals in schools! Discover how schools can adapt to better serve our students in our latest blog post! 🍽️ Read here: [link] #HealthySchools #VeganOptions"
#
# 3. "📢 We need to talk about school lunches! Find out how expanding vegetarian and vegan options can change the game for student health and wellness. 💚✨ [link] #SchoolLunchChallenge"
#
# #### X (formally Twitter) Posts
# 1. "🌿🌟 Is your school serving enough plant-based meals? Explore what’s on the plate and what’s missing! [link] #PlantPower #SchoolLunch"
#
# 2. "📊 Almost 4 in 10 students crave more veggie options in their lunches! Find out how we can make this happen! #HealthyChoices [link]"
#
# 3. "🍽️🌼 It's time to revolutionize school lunches! Discover necessary changes for vegetarian & vegan menus! [link] #LunchReform #BetterChoices"
#
# #### Call to Action:
# "Curious about how the US school system can enhance vegetarian and vegan lunch options? Click the link to read the full blog post and join the conversation on making school lunches healthier and more inclusive for all students! [link]"
#
# Make sure to incorporate visuals, infographics, or data visualizations to enhance the posts where applicable and captivate your audience!

# %%
# The selection function is used to determine which agent should take the next turn in the conversation,
# based on the conversation history and the rules defined in the prompt.

selection_function = KernelFunctionFromPrompt(
    function_name="selection",
    prompt="""
    Based on the conversation history, determine the next agent to take a turn. 
    Only return the name of the agent from the following list:
    - LeadResearchAgent
    - DataAnalystAgent
    - ContentCreatorAgent
    - QualityAssuranceAgent

    Rules:
    - LeadResearchAgent starts first.
    - After LeadResearchAgent, DataAnalystAgent speaks.
    - After DataAnalystAgent, ContentCreatorAgent speaks.
    - After ContentCreatorAgent speaks, the QualityAssuranceAgent speaks.
    - If the QualityAssuranceAgent requests changes, restart the cycle with the LeadResearchAgent.
    - If the QualityAssuranceAgent approves the content, the cycle ends.
   
    History:
    {{$history}}
    """,
)

# %%
# The termination function is used to determine when the conversation should end.
# It checks if the content produced by the agents is complete and valid JSON.

termination_function = KernelFunctionFromPrompt(
    function_name="termination",
    prompt="""
    Determine if the structured content output (article and social_media_posts) are complete.
    If the output is complete and valid, respond with "yes". Otherwise, respond with "no".

    History:
    {{$history}}
    """
)

# %%
# We run this to extract the JSON from the final response, and display the article and social media posts in a formatted way.

if final_response is None:
    print("No response received from the agents. Run again. :(")
else:
    try:
        # Attempt to extract JSON from the final response
        # and display the article and social media posts in a formatted way.
        markdown_text = json.loads(final_response)
        article = markdown_text.get("article", {})
        posts = markdown_text.get("social_media_posts", [])
        # Display the article in Markdown format
        article_md = f"# {article.get('title')}\n\n{article.get('content')}\n\n**{article.get('call_to_action')}**"
        display(Markdown(article_md))
        # Display the social media posts
        for post in posts:
            print(f"Platform: {post['platform']}")
            print(textwrap.fill(post['content'], width=60))
            print('-' * 60)

    except json.JSONDecodeError as e:
        # It didn't give us JSON, so we print the final response, which is likey in Markdown format.
        display(Markdown(final_response))
